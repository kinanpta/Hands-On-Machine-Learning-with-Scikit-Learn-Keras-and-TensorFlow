# %% [markdown]
# # Chapter 4: Training Models
#
# **Primary Reference:**
# Aurélien Géron, *Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow (O’Reilly)*

# %% [markdown]
# ## 1. Chapter Summary
#
# This chapter focuses on how machine learning models are trained and how their performance can be controlled and improved. It explains the core ideas behind model training, including cost functions, optimization techniques, and the challenges of underfitting and overfitting.
#
# The chapter also discusses the bias and variance trade-off and introduces methods such as regularization and learning curves to help build models
# that generalize well to unseen data.

# %% [markdown]
# ## 2. Theoretical Explanation
#
# ### 2.1 The Concept of Model Training
#
# Training a machine learning model means finding the set of parameters that
# minimizes the error between the model’s predictions and the actual target
# values. This process is guided by a cost function that measures how far the
# predictions are from the correct outputs.
#
# ---
#
# ### 2.2 Optimization and Gradient Descent
#
# Most machine learning models are trained using optimization algorithms.
# One of the most widely used methods is gradient descent, which works by
# iteratively adjusting model parameters in the direction that reduces the
# cost function.
#
# ---
#
# ### 2.3 Underfitting and Overfitting
#
# Underfitting occurs when a model is too simple to capture the underlying
# patterns in the data. Overfitting happens when a model learns the training
# data too well, including its noise, and performs poorly on new data.
#
# ---
#
# ### 2.4 Bias and Variance Trade-Off
#
# Bias refers to errors caused by overly simplistic assumptions in the
# learning algorithm, while variance refers to errors caused by excessive
# model complexity. A good model finds a balance between bias and variance in
# order to achieve strong generalization.
#
# ---
#
# ### 2.5 Improving Model Generalization
#
# Model performance can be improved by using techniques such as
# regularization, collecting more training data, selecting better features,
# and tuning hyperparameters.

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

X = np.array([[1], [2], [3], [4], [5]])
y = np.array([1.3, 2.1, 2.9, 3.7, 5.2])

model = Pipeline([
    ("poly", PolynomialFeatures(degree=2)),
    ("linear", LinearRegression())
])

model.fit(X, y)

y_pred = model.predict(X)
mse = mean_squared_error(y, y_pred)

print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.011200000000000009

# %% [markdown]
# ## 3. Code Explanation
#
# This example demonstrates how model complexity affects learning. A
# polynomial regression model is trained on the dataset using a pipeline.
# The mean squared error is used to evaluate how well the model fits the
# training data.

# %% [markdown]
# ## 4. Discussion and Conclusion
#
# This chapter emphasizes the importance of proper model training and
# evaluation. By understanding optimization, overfitting, and the
# bias-variance trade-off, students can build models that are more reliable
# and perform well on new data.
