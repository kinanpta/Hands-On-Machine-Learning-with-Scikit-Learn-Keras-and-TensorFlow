# %% [markdown]
# # Chapter 9: Unsupervised Learning Techniques
#
# **Primary Reference:**
# Aurélien Géron, *Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow (O’Reilly)*

# %% [markdown]
# ## 1. Chapter Summary
#
# This chapter focuses on unsupervised learning, where models learn patterns
# from data without labeled outputs. Unsupervised learning is useful when
# working with large datasets that do not contain explicit target labels.
#
# The chapter introduces several important unsupervised techniques, such as
# clustering and anomaly detection, and explains how these methods are used
# in real-world applications.

# %% [markdown]
# ## 2. Theoretical Explanation
#
# ### 2.1 Understanding Unsupervised Learning
#
# Unsupervised learning aims to discover hidden patterns or structures in
# data without using labeled examples. The model organizes data based on
# similarity and distribution properties.
#
# ---
#
# ### 2.2 Clustering
#
# Clustering is one of the most common unsupervised learning techniques. It
# groups data points into clusters so that samples in the same group are
# more similar to each other than to those in other groups.
#
# ---
#
# ### 2.3 Anomaly Detection
#
# Anomaly detection focuses on identifying unusual or abnormal data points
# that do not follow normal patterns. This technique is widely used in
# fraud detection, network security, and system monitoring.
#
# ---
#
# ### 2.4 Applications of Unsupervised Learning
#
# Unsupervised learning is applied in customer segmentation, recommendation
# systems, image compression, and exploratory data analysis.

# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

data = load_iris()
X = data.data

model = KMeans(n_clusters=3, random_state=42)
labels = model.fit_predict(X)

score = silhouette_score(X, labels)
print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.5511916046195919
# c:\Users\LENOVO\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\LENOVO\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "c:\Users\LENOVO\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\LENOVO\anaconda3\Lib\subprocess.py", line 1039, in __init__
# ...

# %% [markdown]
# ## 3. Code Explanation
#
# This example demonstrates how clustering groups similar data points using
# the K-Means algorithm. The silhouette score measures how well the data has
# been clustered.

# %% [markdown]
# ## 4. Discussion and Conclusion
#
# This chapter shows that unsupervised learning provides valuable insight
# into data structure even without labeled information. These techniques are
# essential for discovering patterns in large and complex datasets.
